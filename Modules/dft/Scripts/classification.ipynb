# %%
import sys
sys.path.append('../lib/')
from FDA_Model import *
from Feature_Extraction import *
import cv2

# %%
# upload model
fda_model = FDA()

# %%
# upload real and fake videos
real_capture = cv2.VideoCapture('../../../../archive/original_sequences/youtube/c23/videos/000.mp4')
fake_capture = cv2.VideoCapture('../../../../archive/manipulated_sequences/FaceSwap/c23/videos/000_003.mp4')

# %%
# classification test
real_capture_result = fda_model.predict(real_capture)
fake_capture_result = fda_model.predict(fake_capture)
# Out:
# c:\Users\omara\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\omara\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\omara\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\omara\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\omara\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
# ...

# %%
print(fake_capture_result)
print(real_capture_result)
# Out:
# {'deepfake': 0, 'face2face': 0, 'faceswap': 0, 'neuraltextures': 0}
# {'deepfake': 0, 'face2face': 0, 'faceswap': 0, 'neuraltextures': 0}
